# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
cd ../
# Out:
# /efs/mm/gymlob

# %%
from gymlob.simulator.agent.marketreplay.LOBSTERMarketReplayAgent import LOBSTERProcessor

# %%
abides_df = pd.read_pickle('log/TSLA_2015-01-02/TSLA_2015-01-02_orderbook.bz2')

# %%
abides_df.head()
# Out:
#                                ORDER_ID   PRICE    SIZE  BUY_SELL_FLAG  \
# 2015-01-02 09:30:00.034289918         1  2.2291  1507.0          False
# 2015-01-02 09:30:00.034289918       316  2.2215   100.0           True
# 2015-01-02 09:30:00.034289918       315  2.2410   100.0          False
# 2015-01-02 09:30:00.034289918       314  2.2222   200.0           True
# 2015-01-02 09:30:00.034289918       313  2.2400   250.0          False
#
#                                       TYPE  ask_price_1  ask_size_1  \
# 2015-01-02 09:30:00.034289918  LIMIT_ORDER   222.910004     34661.0
# 2015-01-02 09:30:00.034289918  LIMIT_ORDER   222.910004     34661.0
# 2015-01-02 09:30:00.034289918  LIMIT_ORDER   222.910004     34661.0
# 2015-01-02 09:30:00.034289918  LIMIT_ORDER   222.910004     34661.0
# 2015-01-02 09:30:00.034289918  LIMIT_ORDER   222.910004     34661.0
#
#                                bid_price_1  bid_size_1  MID_PRICE  SPREAD  \
# ...

# %%
lobster_loader = LOBSTERProcessor(symbol='TSLA',
                                  date=pd.to_datetime('2015-01-02'),
                                  orderbook_file_path='../lobrep/data/TSLA_2015-01-01_2015-01-31_10/TSLA_2015-01-02_34200000_57600000_orderbook_10.csv',
                                  message_file_path='../lobrep/data/TSLA_2015-01-01_2015-01-31_10/TSLA_2015-01-02_34200000_57600000_message_10.csv')
# Out:
# OrderBookOracle Message File: ../lobrep/data/TSLA_2015-01-01_2015-01-31_10/TSLA_2015-01-02_34200000_57600000_message_10.csv
# OrderBookOracle Orderbook File: ../lobrep/data/TSLA_2015-01-01_2015-01-31_10/TSLA_2015-01-02_34200000_57600000_orderbook_10.csv
# OrderBookOracle initialized for TSLA and date: 2015-01-02 00:00:00

# %%
lobster_loader.orderbook_df.head()
# Out:
#                                ask_price_1  ask_size_1  bid_price_1  \
# timestamp
# 2015-01-02 09:30:00.034289918       222.91        1507       222.75
# 2015-01-02 09:30:00.078873974       222.91        1507       222.75
# 2015-01-02 09:30:00.263563035       222.91        1507       222.75
# 2015-01-02 09:30:00.352703503       222.91        1507       222.75
# 2015-01-02 09:30:00.352821417       222.91        1507       222.64
#
#                                bid_size_1  ask_price_2  ask_size_2  \
# timestamp
# 2015-01-02 09:30:00.034289918          11        223.0          26
# 2015-01-02 09:30:00.078873974          11        223.0          26
# 2015-01-02 09:30:00.263563035          11        223.0          26
# 2015-01-02 09:30:00.352703503          10        223.0          26
# 2015-01-02 09:30:00.352821417         300        223.0          26
#
#                                bid_price_2  bid_size_2  ask_price_3  \
# timestamp
# ...

# %%
lobster_mid = (lobster_loader.orderbook_df['ask_price_1'] + lobster_loader.orderbook_df['bid_price_1']) / 2
lobster_mid.plot()
(abides_df['MID_PRICE']*100).plot()
# Out:
# <AxesSubplot:xlabel='timestamp'>
